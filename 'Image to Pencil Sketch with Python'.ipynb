# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\dell-pc\anaconda3\lib\site-packages (4.5.5.62)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: numpy>=1.14.5; python_version >= "3.7" in c:\users\dell-pc\anaconda3\lib\site-packages (from opencv-python) (1.22.2)

# %%
import  cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def show(title,img,cmap='demo'):
    plt.imshow(img,cmap=cmap)
    plt.title(title)

# %%
image=plt.imread("bunny-car.jpeg")
show("car",image,'RdBu')
#cv2.imshow("car",image)
#cv2.waitKey(0)

# %%
gray_image=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
show("gray_image",gray_image,'gray')
#cv2.imshow("gray_image",gray_image)
#cv2.waitKey(0)

# %%
inverted_image =255-gray_image
show("inverted_image",inverted_image,'gray')
#cv2.imshow("inverted_image",inverted_image)
#cv2.waitKey(0)

# %%
blurred_image =cv2.GaussianBlur(inverted_image,(21,21),0)
show("blurred_image",blurred_image,'gray')
#cv2.imshow("blurred_image",blurred_image)
#cv2.waitKey(0)

# %%
inverted_blurred=255-blurred_image
pencil_sketch=cv2.divide(gray_image,inverted_blurred,scale=256.0)
show("pencil_sketch",pencil_sketch,'gray')
